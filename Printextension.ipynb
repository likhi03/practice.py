# %%
filename = input("Input the filename:")
# Out:
# Input the filename:abc.py

# %%
f_exts = filename.split(".")

# %%
print("The extension is :" + repr(f_exts[-1]))
# Out:
# The extension is :'py'
